# %% [markdown]
# # The geometry of equations
#
# ### n linear equations, n unknowns
# ### row picture
# ### column picture
# ### matrix form

# %% [markdown]
# $$2x-y=0$$
# $$-x+2y=3$$

# %% [markdown]
# What's the matrix? that is, what's the coefficient matrix? The matrix that involes these numbers, a matrix is just a rectangular array of numbers.

# %% [markdown]
# $\begin{pmatrix} 2&-1 \\ -1&2 \end{pmatrix} \begin{pmatrix} x \\ y \end{pmatrix} = \begin{pmatrix} 0 \\ 3 \end{pmatrix}$

# %% [markdown]
# ### row picture

# %%
from mpl_toolkits.axisartist.axislines import SubplotZero
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = SubplotZero(fig, 111)
fig.add_subplot(ax)

for direction in ["xzero", "yzero"]:
    # adds arrows at the ends of each axis
    ax.axis[direction].set_axisline_style("-|>")

    # adds X and Y-axis from the origin
    ax.axis[direction].set_visible(True)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax.axis[direction].set_visible(False)

x = np.linspace(-5, 5, 10)
y1 = 2 * x
y2 = (3 + x) / 2

ax.plot(x, y1)
ax.plot(x, y2)
plt.show()

# %% [markdown]
# ### column picture
# the most of fundamental operation is a linear combination of column

# %% [markdown]
# $x\begin{pmatrix} 2&-1 \\ -1&2 \end{pmatrix}  + y\begin{pmatrix} x \\ y \end{pmatrix} = \begin{pmatrix} 0 \\ 3 \end{pmatrix}$

# %%
fig = plt.figure()
ax = SubplotZero(fig, 111)
fig.add_subplot(ax)

for direction in ["xzero", "yzero"]:
    # adds arrows at the ends of each axis
    ax.axis[direction].set_axisline_style("-|>")

    # adds X and Y-axis from the origin
    ax.axis[direction].set_visible(True)

for direction in ["left", "right", "bottom", "top"]:
    # hides borders
    ax.axis[direction].set_visible(False)

x = np.linspace(-5, 5, 10)
y1 = 2 * x
y2 = (3 + x) / 2

ax.plot(x, y1)
ax.plot(x, y2)
plt.show()
